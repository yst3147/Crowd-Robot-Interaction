# %% [markdown]
# ## Google Drive mounting

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

os.chdir('/content/drive/MyDrive/ColabFiles/robotvision/')

# %% [markdown]
# ## Python download

# %%
#!wget https://www.python.org/ftp/python/3.6.8/Python-3.6.8.tgz
# !tar xvfz Python-3.6.8.tgz
# !Python-3.6.8/configure
# !make
# !sudo make install

# %% [markdown]
# ## Envirorment setting

# %%
# %cd Python-RVO2
# !pip install -r requirements.txt
# !python setup.py build
! python setup.py install

# %%
# %cd ..

# %%
# !git clone https://github.com/LynAlpha/social-nce

# %%
# %cd social-nce

# %%
# !git pull
# !pip install -e .
# !pip install gym==0.10.0

# %% [markdown]
# ## Download data

# %%
# %cd crowd_nav
# !mkdir data/demonstration/ -p
# %cd data/demonstration
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1D2guAxD_EgrKnJFMcLSBkf10SOagz0mr

# %%
# %cd ..
# %cd ..

# %% [markdown]
# ### train & test in varnilla

# %%
# !python imitate.py --contrast_weight=0.0 --gpu
# !python test.py --policy='sail' --circle --model_file=data/output/imitate-vanilla-data-0.50/policy_net.pth

# %% [markdown]
# ### train & test in local sampling version

# %%
# !python imitate.py --contrast_weight=2.0 --contrast_sampling='local' --gpu
# !python test.py --policy='sail' --circle --model_file=data/output/imitate-local-data-0.50-weight-2.0-horizon-4-temperature-0.20-nboundary-0-range-2.00/policy_net.pth

# %% [markdown]
# ### train & test in event sampling version

# %%
# !python imitate.py --contrast_weight=2.0 --contrast_sampling='event' --gpu
# !python test.py --policy='sail' --circle --model_file=data/output/imitate-event-data-0.50-weight-2.0-horizon-4-temperature-0.20-nboundary-0/policy_net.pth

# %% [markdown]
# ### Compare

# %%
# !bash script/run_vanilla.sh

# %%
# !bash script/run_local.sh

# %%
# !bash script/run_snce.sh

# %%
# !python utils/compare.py

# %% [markdown]
# ### Test for square crossing and making video(failure)

# %%
# !python test.py --policy='sail' --square --model_file=data/output/imitate-event-data-0.50-weight-2.0-horizon-4-temperature-0.20-nboundary-0/policy_net.pth

# %%
# !python test.py --policy='sail' --square --model_file=data/output/imitate-event-data-0.50-weight-2.0-horizon-4-temperature-0.20-nboundary-0/policy_net.pth --visualize --test_case 1

# %%
# !python test.py --policy='sail' --mixed --model_file=data/output/imitate-event-data-0.50-weight-2.0-horizon-4-temperature-0.20-nboundary-0/policy_net.pth
