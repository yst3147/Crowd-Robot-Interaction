# %% [markdown]
# ## Google Drive mounting

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

os.chdir('/content/drive/MyDrive/ColabFiles/robotvision/')

# %% [markdown]
# ## Python download

# %%
# !wget https://www.python.org/ftp/python/3.6.8/Python-3.6.8.tgz
# !tar xvfz Python-3.6.8.tgz
# !Python-3.6.8/configure
# !make
# !sudo make install

# %% [markdown]
# ## Envirorment setting

# %%
# !git clone https://github.com/sybrenstuvel/Python-RVO2.git

# %%
# %cd Python-RVO2
# !pip install -r requirements.txt
# !python setup.py build
! python setup.py install

# %%
# %cd ..

# %%
# !git clone https://github.com/LynAlpha/CrowdNav

# %%
# %cd CrowdNav
# !git pull
# !pip install -e .

# %%
# !pip install gym==0.10.0

# %%
# %cd crowd_nav

# %% [markdown]
# ### train

# %%
# !python train.py --policy sarl --gpu --resume

# %% [markdown]
# ### test

# %%
# !python test.py --policy sarl --model_dir data/output --phase test --gpu

# %% [markdown]
# ### test(video file making)

# %%
# !python test.py --policy sarl --model_dir data/output --phase test --visualize --test_case 0 --gpu --traj --video_file data/output/output_sarl_traj.png

# %%
# !python test.py --policy sarl --model_dir data/output --phase test --visualize --test_case 0 --gpu --video_file data/output/output_sarl.mp4

# %% [markdown]
# ### test(square scenario)

# %%
# !python test.py --policy sarl --square --model_dir data/output --phase test --gpu
